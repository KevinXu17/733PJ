# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset, DataLoader

# %%
# data = pd.read_csv('archive/Reviews.csv')
# data[data['HelpfulnessDenominator'] >= 10].count()

# %%
df = pd.read_csv('amazon_reviews_us_Wireless_v1_00.tsv.gz',sep='\t', on_bad_lines='skip')
# Out:
# /var/folders/xn/m2m6g5q50gq03pjb2l3zcnj80000gn/T/ipykernel_17489/503401332.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('amazon_reviews_us_Wireless_v1_00.tsv.gz',sep='\t', on_bad_lines='skip')
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 2731             US     19380011  R2AYJHH8WJNGAU  B013D32WVA       138975975
# 3706             US       113760   RZOPM62JMW97V  B00X0X3EQ6       657509542
# 5185             US     44137838  R2WYKBQS8OR08O  B010GYYSU2       518226514
# 7585             US     48852155  R1MAOLI5FJHAFM  B013X0V11K       610966690
# 9110             US     30990049   R6RPTEPYT9J29  B011BEA4V8       666771374
# ...             ...          ...             ...         ...             ...
# 8991555          US     50891732  R1FPMHRB1KOHY6  B00001W0EX       805709050
# 8991559          US     51134141  R1SQ6DT3YP13XE  B00001O37W       993543357
# ...

# %%
df[df['total_votes'] >= 50].count()
# Out:
# marketplace          21650
# customer_id          21650
# review_id            21650
# product_id           21650
# product_parent       21650
# product_title        21650
# product_category     21650
# star_rating          21650
# helpful_votes        21650
# total_votes          21650
# vine                 21650
# verified_purchase    21650
# review_headline      21650
# review_body          21641
# review_date          21650
# dtype: int64

# %%
#df1 = pd.read_csv('amazon_reviews_us_Electronics_v1_00.tsv.gz',sep='\t', on_bad_lines='skip')
df1[df1['total_votes'] >= 50].count()
# Out:
# marketplace          17424
# customer_id          17424
# review_id            17424
# product_id           17424
# product_parent       17424
# product_title        17424
# product_category     17424
# star_rating          17424
# helpful_votes        17424
# total_votes          17424
# vine                 17424
# verified_purchase    17424
# review_headline      17424
# review_body          17423
# review_date          17423
# dtype: int64

# %%
# df2 = pd.read_csv('amazon_reviews_us_Mobile_Electronics_v1_00.tsv.gz',sep='\t', on_bad_lines='skip')
df2[df2['total_votes'] >= 50].count()
# Out:
# marketplace          311
# customer_id          311
# review_id            311
# product_id           311
# product_parent       311
# product_title        311
# product_category     311
# star_rating          311
# helpful_votes        311
# total_votes          311
# vine                 311
# verified_purchase    311
# review_headline      311
# review_body          311
# review_date          311
# dtype: int64

# %%
# df3 = pd.read_csv('amazon_reviews_us_PC_v1_00.tsv.gz',sep='\t', on_bad_lines='skip')
df3[df3['total_votes'] >= 50].count()
# Out:
# marketplace          28973
# customer_id          28973
# review_id            28973
# product_id           28973
# product_parent       28973
# product_title        28973
# product_category     28973
# star_rating          28973
# helpful_votes        28973
# total_votes          28973
# vine                 28973
# verified_purchase    28973
# review_headline      28973
# review_body          28968
# review_date          28972
# dtype: int64

# %%
#df4 = pd.read_csv('amazon_reviews_us_Major_Appliances_v1_00.tsv.gz',sep='\t', on_bad_lines='skip')
df4[df4['total_votes'] >= 50].count()
# Out:
# marketplace          1404
# customer_id          1404
# review_id            1404
# product_id           1404
# product_parent       1404
# product_title        1404
# product_category     1404
# star_rating          1404
# helpful_votes        1404
# total_votes          1404
# vine                 1404
# verified_purchase    1404
# review_headline      1404
# review_body          1403
# review_date          1404
# dtype: int64
